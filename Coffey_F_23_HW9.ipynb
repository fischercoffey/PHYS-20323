# %% [markdown]
# # Phyiscs Problems - Lectures 18 & 19 - Homework 9
#
# FALL 2023

# %% [markdown]
# ### 1) Altitude of a satellite
#
# A satellite is to be launched into a circular orbit around the Earth so that it orbits the planet once every T seconds.
#
# The altitude h above the Earth’s surface that the satellite must have is:
#
# $$h = \left( \frac{G M T^2}{4\pi^2} \right)^{1/3} - R$$
#
# where $G = 6.67 \times 10^{-11}$ m$^3$ kg$^{-1}$ s$^{-2}$
# is Newton's gravitational constant, $M = 5.97 \times 10^{24}$ kg is the mass of the Earth, and $R = 6371$ km is its radius.
#
# #### Write a program that asks the user to enter the desired value of T and then calculates and prints out the correct altitude in meters.

# %%
import numpy as np


T = float(input('Enter desired value of T: '))
G = 6.67 * 10 **-11
M = 5.97 * 10 **24
R = 6371000


h = (((G*M*T**2) / (4 * np.pi** 2)) ** (1/3)) - R
print(h)
# Out:
# Enter desired value of T: 86400
# 35855910.17617497

# %% [markdown]
# Use your program to calculate the altitudes of satellites that orbit the Earth once
# a day (so-called “geosynchronous” orbit), once every 90 minutes, and once every
# 45 minutes. What do you conclude from the last of these calculations?

# %%
import numpy as np

# Time translated to seconds, because I fear if I try and make it accept minutes it will break.
# Times to be used in order, 86400, 5400, 2700
# Answers to viewed as meters

T = float(input('Enter desired value of T: '))
G = 6.67 * 10 **-11
M = 5.97 * 10 **24
R = 6371000

h = (((G*M*T**2) / (4 * np.pi** 2)) ** (1/3)) - R
print(h)

T90 = float(input('Enter desired value of T: '))
G = 6.67 * 10 **-11
M = 5.97 * 10 **24
R = 6371000

h90 = (((G*M*T90**2) / (4 * np.pi** 2)) ** (1/3)) - R
print(h90)

T45 = float(input('Enter desired value of T: '))
G = 6.67 * 10 **-11
M = 5.97 * 10 **24
R = 6371000

h45 = (((G*M*T45**2) / (4 * np.pi** 2)) ** (1/3)) - R
print(h45)
# Out:
# Enter desired value of T: 86400
# 35855910.17617497
# Enter desired value of T: 5400
# 279321.62537285965
# Enter desired value of T: 2700
# -2181559.8978108233

# %% [markdown]
# Technically a geosynchronous satellite is one that orbits the Earth once persidereal
# day, which is 23.93 hours, not 24 hours. Why is this? And how much difference
# will it make to the altitude of the satellite?

# %%
import numpy as np

# Time translated to seconds, because I fear if I try and make it accept minutes it will break.
# Answer to viewed as meters
# Use 86148 seconds for 23.93 hours

T = float(input('Enter desired value of T: '))
G = 6.67 * 10 **-11
M = 5.97 * 10 **24
R = 6371000

h = (((G*M*T**2) / (4 * np.pi** 2)) ** (1/3)) - R
print(h)
# Out:
# Enter desired value of T: 86148
# 35773762.329895645

# %% [markdown]
# #### Modify your code to calculate the times from 0.5 hour  to 30 days, in steps of 0.5 hours.   Then plot those data points (time vs h) with properly labled axes.  Plot orbits with height below 0 as red, and plots positive heights with times less than geosynchronous in blue and those longer in green.

# %%
import matplotlib.pyplot as plt
import numpy as np
 

ts = []
hs = []
for T in np.arange(.5, 720, .5):
    G = 6.67 * 10 **-11
    M = 5.97 * 10 **24
    R = 6371000
    Tsec = T*60*60
    h = (((G*M*Tsec**2) / (4 * np.pi** 2)) ** (1/3)) - R
    hs.append(h)
    ts.append(T)
    
hs = np.array(hs)
ts = np.array(ts)
below = hs<0
mid = (hs>0) & (ts<24)



print(h)

fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111)
ax.scatter([ts],[hs],s=20,alpha=0.3)
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
ax.set_ylabel("Height (m)",size=15) 
ax.set_xlabel("Period (hours)",size=15)



plt.scatter(ts, hs, c='g', label = 'Greater than the Geosynchronus')
plt.scatter(ts[mid], hs[mid], c='b',label ='Above ground but less than geosynchronus')
plt.scatter(ts[below], hs[below],c ='r', label = 'below ground')
plt.legend()
# Out:
# 401136565.04197764

# %% [markdown]
# ### 2) Special Relativity
#
# A spaceship travels from Earth in a straight line at a (relativistic)
# speed $v$ to another planet $x$ light years away. Write a program to ask
# the user for the value of $x$ and the speed $v$ as a fraction of the speed
# of light, then print out the time in years that the spaceship takes to
# reach its destination (a) in the rest frame of an observer on Earth
# and (b) as perceived by a passenger on board the ship.
#
# $$x' = \gamma (x - vt)$$
#
# $$t' = \gamma \left(t - \frac{v x}{c^2}\right)$$
#
# $$\gamma = \frac{1}{\sqrt{1 - \frac{v^2}{c^2}}}$$

# %%
import math

v = float(input('Input value for speed: '))
x = float(input('Input value for distance in light years: '))
c = 2.99e8
                
t = x/v            
gm = math.sqrt(1 - (v**2))                
tp = gm * (t - ((v*x)/c))

print(gm)
print(t)
print(tp)
# Out:
# Input value for speed: .9
# Input value for distance in light years: 10
# 0.4358898943540673
# 11.11111111111111
# 4.843221035258093

# %% [markdown]
# #### Use your program to calculate the answers for a planet 10 light years away with $v = 0.90c$,  $v = 0.98c$, $v = 0.999c$.

# %%
import math

v = float(input('Input value for speed: '))
x = float(input('Input value for distance in light years: '))
c = 2.99e8
                
t = x/v            
gm = math.sqrt(1 - (v**2))                
tp = gm * (t - ((v*x)/c))

print(gm)
print(t)
print(tp)
###############################################
v1 = float(input('Input value for speed: '))
x1 = float(input('Input value for distance in light years: '))
c1 = 2.99e8
                
t1 = x1/v1            
gm1 = math.sqrt(1 - (v1**2))                
tp1 = gm1 * (t1 - ((v1*x1)/c1))

print(gm1)
print(t1)
print(tp1)
##############################################
v2 = float(input('Input value for speed: '))
x2 = float(input('Input value for distance in light years: '))
c2 = 2.99e8
                
t2 = x2/v2            
gm2 = math.sqrt(1 - (v2**2))                
tp2 = gm2 * (t2 - ((v2*x2)/c2))

print(gm2)
print(t2)
print(tp2)
# Out:
# Input value for speed: .9
# Input value for distance in light years: 10
# 0.4358898943540673
# 11.11111111111111
# 4.843221035258093
# Input value for speed: .98
# Input value for distance in light years: 10
# 0.1989974874213242
# 10.204081632653061
# 2.0305865998177173
# Input value for speed: .999
# Input value for distance in light years: 10
# 0.04471017781221601
# 10.01001001001001
# 0.4475493259557814

# %% [markdown]
# ### 3) The quadratic equation
#
#  Write a program that takes as input three numbers, $a$, $b$, and $c$, and prints out the two solutions to the quadratic equation $ax^2 + bx + c = 0$ using the standard
# formula:
#
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$
#
# Use your program to compute the solutions of $0.001x^2 + 1000x + 0.001 = 0$.

# %%
import math
import numpy as np

a = float(input('Enter value for a: '))
b = float(input('Input value for b: '))
c = float(input('Input value for c: '))

x = -b +- np.sqrt((b**2) - 4*a*c)/2*a

print(x)

O = a*(x**2)+b*x+c
print(O)
# Out:
# Enter value for a: .001
# Input value for b: 1000
# Input value for c: .001
# -1000.499999999999
# -999498.9987499989

# %% [markdown]
# There is another way to write the solutions to a quadratic equation. Multiplying top and bottom of the solution above by $-b \mp \sqrt{b^2 - 4ac}$, show that the solutions
# can also be written as:
#
# $$x = \frac{2c}{-b \mp \sqrt{b^2 - 4ac}}$$
#
# Add further lines to your program to print these values in addition to the earlier ones and again use the program to solve $0.001x^2 + 1000x + 0.001 = 0$. What do you see? How do you explain it?

# %%
import math
import numpy as np

a = float(input('Enter value for a: '))
b = float(input('Input value for b: '))
c = float(input('Input value for c: '))

x = 2*c/-b -+ np.sqrt(b**2 - 4*a*c)

print(x)

O = a*(x**2)+b*x+c
print(O)
# Out:
# Enter value for a: .001
# Input value for b: 1000
# Input value for c: .001
# -1000.000001998
# -999000.000994004

# %%
import math

def sol1(a,b,c):
    D = b*b -4*a*c
    print(D)
    
    x = (-b + math.sqrt(D))/(2*a)
    y = (-b - math.sqrt(D))/(2*a)
    
return x,y

print(sol1(0.001,1000,0.001))

def sol2(a,b,c):
    D = b*b -4*a*c
    print(D)
    
    x = (2*c)/(-b - math.sqrt(D))
    y = (2*c)/(-b + math.sqrt(D))

return x,y

print(sol2(0.001,1000,0.001))

def solall(a,b,c):
    D = b*b -4*a*c
    
    if D >= 0:
        x = (-b + math.sqrt(D))/(2*a)
        y = (-b - math.sqrt(D))/(2*a)
    else:
        real = -b/(2*a)
        img = math.sqrt(-1*D)/(2*a)
        x = str(real) + " + " + "i"+ str(img)
        y = str(real) + " - " + "i"+ str(img)
        

        return x,y

print(solall(1,4,5))
# Out:
#   Cell In[1], line 11
#     return x,y
#     ^
# SyntaxError: 'return' outside function

# %% [markdown]
# Using what you have learned, write a new program that calculates both roots of a quadratic equation accurately in all cases.

# %% [markdown]
# ### 4) Planetary orbits
#
# The orbit in space of one body around another, such as a planet around the Sun, need not be circular. In general it takes the form of an ellipse, with the body sometimes closer in and sometimes further out. If you are given the distance $l_1$ of closest approach that a planet makes to the Sun, also called its perihelion, and its linear velocity $v_1$ at *perihelion*, then any other property of the orbit can be calculated from these two as follows.
#
# Kepler’s second law tells us that the distance $l_2$ and velocity $v_2$ of the planet at its most distant point, or *aphelion*, satisfy $l_2 v_2 = l_1 v_1$.
#
#
# Given the values of $v_1$, $l_1$, and $l_2$, other parameters of the orbit are given by simple formulas can that be derived from Kepler’s laws and the fact that the orbit is an ellipse:
#
# Semi-Major Axis $$ a = \frac{1}{2} (l_1 + l_2) $$
# Semi-Minor Axis: $$ b = \sqrt{l_1  l_2} $$
# Orbital Period: $$ T = \frac{2 \pi a b}{l_1 v_1} $$
# Orbital eccentricity:  $$ e = \frac{l_2 - l_1}{l_2 + l_1}$$
#
# #### Write a program with functions that asks the user to enter the distance to the Sun and velocity at perihelion, then calculates and prints the quantities $l2$, $v2$, $a$, $b$, $T$, and $e$.

# %%
from math import pi
l1=float(input('Enter value for l2: '))
v1=float(input('Enter value for v1: '))
G=6.6738*10**-11
M=1.9891*10**30
#calculating constants b and c for ax^2+bx+c, a is 1
a=1
b=-2*G*M/(v1*l1)
c=-(v1**2-2*G*M/l1)
D=b*b-4*a*c
root1=(-b-D**.5)/2
root2=(-b+D**.5)/2
v2=min([root1,root2])
l2=l1*v1/v2
a=.5*(l1+l2)
b=(l1*l2)**.5
T=(2*pi*a*b)/(l1*v1)/(24*60*60)/365#converted to years
e=(l2-l1)/(l2+l1)
print(l2)
print(v2)
print(a)
print(b)
print(T)
print(e)
# Out:
# Enter value for l2: 0
# Enter value for v1: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 8
#       6 #calculating constants b and c for ax^2+bx+c, a is 1
#       7 a=1
# ----> 8 b=-2*G*M/(v1*l1)
#       9 c=-(v1**2-2*G*M/l1)
#      10 D=b*b-4*a*c
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# #### Test your program by having it calculate the properties of the orbits of the Earth (for which $l_1 = 1.4710 \times 10^{11}$ m and $v_1 = 3.0287 \times 10^4$ m s$^{−1}$ ) and Halley’s comet ($l_1 = 8.7830 \times 10^{10}$ m and $v_1 = 5.4529 \times 10^4$ m s${−1}$ ). Among other things, you should find that the orbital period of the Earth is one year and that of Halley’s comet is about 76 years.

# %%
from math import pi
l1=float(input('Enter value for l2: '))
v1=float(input('Enter value for v1: '))
G=6.6738*10**-11
M=1.9891*10**30
#calculating constants b and c for ax^2+bx+c, a is 1
a=1
b=-2*G*M/(v1*l1)
c=-(v1**2-2*G*M/l1)
D=b*b-4*a*c
root1=(-b-D**.5)/2
root2=(-b+D**.5)/2
v2=min([root1,root2])
l2=l1*v1/v2
a=.5*(l1+l2)
b=(l1*l2)**.5
T=(2*pi*a*b)/(l1*v1)/(24*60*60)/365#converted to years
e=(l2-l1)/(l2+l1)
print(l2)
print(v2)
print(a)
print(b)
print(T)
print(e)
# Out:
# Enter the perihelion in meters: 1.471e11
# Enter the velocity at perihelion in m/s: 3.0287e4
# l2 = 152203426488.95538 meters
# v2 = 29271.467816286593 m/s
# a = 149651713244.4777 meters
# b = 149629957015.71707 meters
# T = 1.0013930557484005 years
# e = 0.017051012575506567

# %%
from math import pi
l1=float(input('Enter value for l2: '))
v1=float(input('Enter value for v1: '))
G=6.6738*10**-11
M=1.9891*10**30
#calculating constants b and c for ax^2+bx+c, a is 1
a=1
b=-2*G*M/(v1*l1)
c=-(v1**2-2*G*M/l1)
D=b*b-4*a*c
root1=(-b-D**.5)/2
root2=(-b+D**.5)/2
v2=min([root1,root2])
l2=l1*v1/v2
a=.5*(l1+l2)
b=(l1*l2)**.5
T=(2*pi*a*b)/(l1*v1)/(24*60*60)/365#converted to years
e=(l2-l1)/(l2+l1)
print(l2)
print(v2)
print(a)
print(b)
print(T)
print(e)
# Out:
# Enter the perihelion in meters: 8.7830e10
# Enter the velocity at perihelion in m/s: 5.4529e4
# l2 = 5472738862158.555 meters
# v2 = 875.1161330052964 m/s
# a = 2780284431079.2773 meters
# b = 693304157108.1093 meters
# T = 80.18919937477547 years
# e = 0.9684097069284723
