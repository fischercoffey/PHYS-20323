# %% [markdown]
# ## Python Data fitting with various functions - HW 11 part 2
# Due Friday Nov 10, 2023
#
#
# Dowload the data "miniDR17.fits" from the TCU Online Week 12:<br>
# <i>NOTE: it is a large-ish file and may take a while.</i>
#
# **However, this is a small version of the full science data file (4 GB) which can be found at:**<br>
# https://data.sdss.org/sas/dr17/apogee/spectro/aspcap/dr17/synspec_rev1/allStar-dr17-synspec_rev1.fits
#
#
# You will be using the same data "miniDR17.fits" from the TCU Online Week 12:<br>
#
# Remember you need to remove Identified bad data,
# however data that are just bad in one quantity may remain
# Use masking to remove any remaining bad values (typically 9999 or -9999 in this file, <b>but remember to remove Outliers!!!!  If you are not sure, ask!!!</b>).

# %%
from matplotlib import pyplot as plt
import numpy as np
from astropy.io import fits 
import scipy.optimize as opt

# POTENTIAL FITTING FUNCTIONS
def linear(x,m,b):
    return m*x+b

def poly2(x,a,b,c):
    return a*(x**2)+(b*x)+c

def poly3(x,a,b,c,d):
    return (a*(x**3))+(b*(x**2))+(c*x)+d

def cosfit (x,a,b,c,d):
    return a*np.cos(b*x + c) + d

def exponential(x,a,b,c,d):
    return a*np.exp(b*x + c) + d

def logfit(x,a,b,c,d):
    return a*np.log(b*x + c) + d


# Monte Carlo-version of 2 parameter Curve Fit that can use BOTH x and Y errors
def mcFit2(func, x, y, x_err=0.1, y_err=0.1, p0=[0,0]):
    slope = list()
    y_ints = list()
    iters = 500 
    for i in range(iters):
        # remember random normal distribution (Gaussian)
        weightsx = np.random.randn(len(y))
        weightsy = np.random.randn(len(y))
        y_adj = y + y_err*weightsy
        x_adj = x + x_err*weightsx 
        popt, pcov = opt.curve_fit(func, x_adj, y_adj, p0=p0)
        slope.append(popt[0])
        y_ints.append(popt[1])
    return (np.median(slope),np.median(y_ints))


# Monte Carlo-version of 3 parameter Curve Fit that can use BOTH x and Y errors
def mcFit3(func, x, y, x_err=0.1, y_err=0.1,p0=[1,1,1]):
    paramA = list()
    paramB = list()
    paramC = list()
    iters = 500 
    for i in range(iters):
        # remember random normal distribution (Gaussian)
        weightsx = np.random.randn(len(y))
        weightsy = np.random.randn(len(y))
        y_adj = y + y_err*weightsy
        x_adj = x + x_err*weightsx 
        popt, pcov = opt.curve_fit(func, x_adj, y_adj, p0=p0)
        paramA.append(popt[0])
        paramB.append(popt[1])
        paramC.append(popt[2])
    return (np.median(paramA),np.median(paramB),np.median(paramC))

# Monte Carlo-version of 4 parameter Curve Fit that can use BOTH x and Y errors
def mcFit4(func, x, y, x_err=0.1, y_err=0.1, p0=[1,1,1,1]):
    paramA = list()
    paramB = list()
    paramC = list()
    paramD = list()
    iters = 500 
    for i in range(iters):
        # remember random normal distribution (Gaussian)
        weightsx = np.random.randn(len(y))
        weightsy = np.random.randn(len(y))
        y_adj = y + y_err*weightsy
        x_adj = x + x_err*weightsx 
        popt, pcov = opt.curve_fit(func, x_adj, y_adj, p0=p0)
        paramA.append(popt[0])
        paramB.append(popt[1])
        paramC.append(popt[2])
        paramD.append(popt[3])
    return (np.median(paramA),np.median(paramB),np.median(paramC),np.median(paramD))

# %%
# READ IN FITS FILES
star_hdus = fits.open('miniDR17.fits')
star = star_hdus[1].data
print(star_hdus[1].columns)
star_hdus.close()
# Out:
# ColDefs(
#     name = 'APOGEE_ID'; format = '30A'
#     name = 'RA'; format = 'D'
#     name = 'DEC'; format = 'D'
#     name = 'GLON'; format = 'D'
#     name = 'GLAT'; format = 'D'
#     name = 'TEFF'; format = 'E'
#     name = 'TEFF_ERR'; format = 'E'
#     name = 'LOGG'; format = 'E'
#     name = 'LOGG_ERR'; format = 'E'
#     name = 'J'; format = 'E'
#     name = 'J_ERR'; format = 'E'
#     name = 'K'; format = 'E'
#     name = 'K_ERR'; format = 'E'
#     name = 'SNR'; format = 'E'
#     name = 'VHELIO_AVG'; format = 'E'
#     name = 'VERR'; format = 'E'
#     name = 'FE_H'; format = 'E'
#     name = 'FE_H_ERR'; format = 'E'
#     name = 'O_FE'; format = 'E'
#     name = 'O_FE_ERR'; format = 'E'
#     name = 'NI_FE'; format = 'E'
#     name = 'NI_FE_ERR'; format = 'E'
#     name = 'NVISITS'; format = 'J'
#     name = 'VSCATTER'; format = 'E'
#     name = 'ASPCAPFLAG'; format = 'K'
#     name = 'STARFLAG'; format = 'K'
#     name = 'EXTRATARG'; format = 'J'
# ...

# %%
# TWO BITWISE FLAGS FOR BAD DATA - THESE REMOVE IDENTIFIED BAD DATA            
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

# Make a Boolena Mask to remove bad data
gd = (np.bitwise_and(star['aspcapflag'], badbits) == 0) &\
     (np.bitwise_and(star['starflag'], suspectbits) == 0)
good = np.where(gd)[0]


# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax.scatter((star['TEFF'][good]),star['LOGG'][good],s=1,c='b',alpha=0.1)

ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
ax.set_xlim(21000,2000)
ax.set_ylim(5.8,-1)

plt.show()

# %% [markdown]
# ## DATA FIT 1
#
# Fit a linear, polynomial (poly2), and a polynomial (poly3) functions and to the following selections of the data:
# 1. Select stars only with with $ GLAT > 20$ <br>
#    __Fit Fe\_H,  (Fe\_H\_ERR)  vs.  O\_FE (O\_FE\_ERR)__<br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code, from part 1, and plot the results here

# TWO BITWISE FLAGS FOR BAD DATA - THESE REMOVE IDENTIFIED BAD DATA            
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

# Make a Boolena Mask to remove bad data
gd = (np.bitwise_and(star['aspcapflag'], badbits) == 0) &\
     (np.bitwise_and(star['starflag'], suspectbits) == 0) & (star['GLAT'] > 20) &\
     (star['GLAT'] < 9999) & (~np.isnan(star['Fe_H'])) & (~np.isnan(star['O_Fe']))

good = np.where(gd)[0]


## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['Fe_H'][good], star['O_Fe'][good], star['Fe_H_ERR'][good], \
                          star['O_Fe_ERR'][good], p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')
## POLY2 FIT (3 parameter)
polyA, polyB, polyC, = mcFit3(poly2, star['Fe_H'][good], star['O_Fe'][good], star['Fe_H_ERR'][good], \
                         star['O_Fe_ERR'][good],p0=[1,1,1])
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}')
## POLY3 FIT (3 parameter)
polyA, polyB, polyC, polyD = mcFit4(poly3, star['Fe_H'][good], star['O_Fe'][good], star['Fe_H_ERR'][good]\
                        , star['O_Fe_ERR'][good], p0=[0,0,0,0])
print(f'POLY3: {polyA:.3f}, {polyB:.3}, {polyC:.3f},{polyD:.3f}')

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
#ax.scatter(star['Fe_H_ERR'][good],star['O_Fe_ERR'][good],s=1,c='r',alpha=0.1)

ax.errorbar(star['Fe_H'][good],star['O_FE'][good], xerr=star['FE_H_ERR'][good],
    yerr=(star['O_FE_ERR'][good]), ecolor='grey',fmt='none', capsize=5, zorder=0)
ax.scatter(star['Fe_H'][good],star['O_Fe'][good],s=1,c='b',alpha=0.1)


x_plot = np.linspace(-3,1,1000) # X-PLOTING FOR FITS

ax.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
ax.plot(x_plot,poly2(x_plot, polyA, polyB, polyC), label='Fit: poly2')
ax.plot(x_plot,poly3(x_plot, polyA, polyB, polyC, polyD), label='Fit: poly3')


ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: -0.233, 0.054
# POLY2: -0.073, -0.317, 0.048
# POLY3: 0.075, 0.0921, -0.262,0.045

# %% [markdown]
# ## DATA FIT 2
#
# Fit a linear, polynomial (poly2), and a polynomial (poly3) functions and to the following selections of the data:
# 2. Select stars only with with $-1< GLAT < 1$ <br>
#    __Fit Fe\_H,  (Fe\_H\_ERR)  vs.  O\_FE (O\_FE\_ERR)__<br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code, from part 1, and plot the results here

# TWO BITWISE FLAGS FOR BAD DATA - THESE REMOVE IDENTIFIED BAD DATA            
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

# Make a Boolena Mask to remove bad data
gd = (np.bitwise_and(star['aspcapflag'], badbits) == 0) &\
     (np.bitwise_and(star['starflag'], suspectbits) == 0) & (star['GLAT'] < 1) & (star['GLAT'] > -1) &\
     (star['GLAT'] < 9999) & (~np.isnan(star['Fe_H'])) & (~np.isnan(star['O_Fe']))

good = np.where(gd)[0]


## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['Fe_H'][good], star['O_Fe'][good], star['Fe_H_ERR'][good], \
                          star['O_Fe_ERR'][good], p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')
## POLY2 FIT (3 parameter)
polyA, polyB, polyC, = mcFit3(poly2, star['Fe_H'][good], star['O_Fe'][good], star['Fe_H_ERR'][good], \
                         star['O_Fe_ERR'][good],p0=[1,1,1])
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}')
## POLY3 FIT (3 parameter)
polyA, polyB, polyC, polyD = mcFit4(poly3, star['Fe_H'][good], star['O_Fe'][good], star['Fe_H_ERR'][good]\
                        , star['O_Fe_ERR'][good], p0=[0,0,0,0])
print(f'POLY3: {polyA:.3f}, {polyB:.3}, {polyC:.3f},{polyD:.3f}')

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
#ax.scatter(star['Fe_H_ERR'][good],star['O_Fe_ERR'][good],s=1,c='r',alpha=0.1)

ax.errorbar(star['Fe_H'][good],star['O_FE'][good], xerr=star['FE_H_ERR'][good],
    yerr=(star['O_FE_ERR'][good]), ecolor='grey',fmt='none', capsize=5, zorder=0)
ax.scatter(star['Fe_H'][good],star['O_Fe'][good],s=1,c='b',alpha=0.1)


x_plot = np.linspace(-3,1,1000) # X-PLOTING FOR FITS

ax.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
ax.plot(x_plot,poly2(x_plot, polyA, polyB, polyC), label='Fit: poly2')
ax.plot(x_plot,poly3(x_plot, polyA, polyB, polyC, polyD), label='Fit: poly3')


ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: -0.137, 0.040
# POLY2: -0.020, -0.146, 0.041
# POLY3: 0.089, 0.129, -0.131,0.033

# %% [markdown]
# ## DATA FIT 3
#
# Fit a linear, polynomial (poly3), and a exponetial functions and to the following selections of the data:
# 3. Select stars only with with $340 < GLON < 360$ <br>
#    __Fit TEFF,  (TEFF\_ERR)  vs.  LOGG (LOGG\_ERR)__<br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code and plot the results here

# TWO BITWISE FLAGS FOR BAD DATA - THESE REMOVE IDENTIFIED BAD DATA            
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

# Make a Boolena Mask to remove bad data
gd = (np.bitwise_and(star['aspcapflag'], badbits) == 0) &\
     (np.bitwise_and(star['starflag'], suspectbits) == 0) & (star['GLON'] < 360) & (star['GLON'] > 340) &\
     (star['GLON'] < 9999) & (~np.isnan(star['TEFF'])) & (~np.isnan(star['LOGG']))

good = np.where(gd)[0]


## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['TEFF'][good], star['LOGG'][good], star['TEFF_ERR'][good],\
                          star['LOGG_ERR'][good], p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')
## EXPONENTIAL (3 parameter)
polyA, polyB, polyC, polyD = mcFit4(exponential, star['TEFF'][good], star['LOGG'][good], star['TEFF_ERR'][good],\
                         star['LOGG_ERR'][good],p0=[-70,-0.00035,-1.9,4.7])
print(f'EXPONENTIAL: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}, {polyD:.3f}')
## POLY3 FIT (3 parameter)
polyA2, polyB2, polyC2, polyD2 = mcFit4(poly3, star['TEFF'][good], star['LOGG'][good], star['TEFF_ERR'][good]\
                        , star['LOGG_ERR'][good], p0=[0,0,0,0])
print(f'POLY3: {polyA2:.3f}, {polyB2:.3}, {polyC2:.3f},{polyD2:.3f}')

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
#ax.scatter(star['Fe_H_ERR'][good],star['O_Fe_ERR'][good],s=1,c='r',alpha=0.1)

ax.errorbar(star['TEFF'][good],star['LOGG'][good], xerr=star['TEFF_ERR'][good],
    yerr=(star['LOGG_ERR'][good]), ecolor='grey',fmt='none', capsize=5, zorder=0)
ax.scatter(star['TEFF'][good],star['LOGG'][good],s=1,c='b',alpha=0.1)


x_plot = np.linspace(0,25000,1000) # X-PLOTING FOR FITS

ax.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
ax.plot(x_plot,exponential(x_plot, polyA, polyB, polyC, polyD), label='Fit: exponential')
ax.plot(x_plot,poly3(x_plot, polyA2, polyB2, polyC2, polyD2), label='Fit: poly3')


ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: 0.000, 0.354
# EXPONENTIAL: -64.782, -0.000, -1.774, 4.729
# POLY3: 0.000, -1.74e-07, 0.002,-4.027

# %% [markdown]
# ## DATA FIT 4
#
# Fit  a linear, a logfit, and a polynomial (poly2) functions and to the following selections of the data:
# 4. Select stars only with with $DEC < -50$ and $50 < RA < 120$ <br>
#    __Fit TEFF,  (TEFF\_ERR)   vs.  (J - K) (J\_ERR, K\_ERR)__<br>
# <br>
# NOTE: you will have to create a (J-K) error:  JK_ERR = np.sqrt( J\_ERR^2 + K\_ERR^2 )<br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code and plot the results here

# TWO BITWISE FLAGS FOR BAD DATA - THESE REMOVE IDENTIFIED BAD DATA            
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

JK_ERR = (np.sqrt(star['J_ERR'][good]**2 + star['K_ERR'][good]**2))
JK = (star['J'][good] - star['K'][good])

# Make a Boolena Mask to remove bad data
gd = (np.bitwise_and(star['aspcapflag'], badbits) == 0) &\
     (np.bitwise_and(star['starflag'], suspectbits) == 0) & (star['DEC'] < -50) & (star['RA'] > 50) &\
     (star['RA'] < 120) & (star['TEFF'] < 9999) & (~np.isnan(star['TEFF'])) & (~np.isnan(star['O_Fe']))

good = np.where(gd)[0]


## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['TEFF'][good], (star['J'][good] - star['K'][good]), star['TEFF_ERR'][good],\
                          (np.sqrt(star['J_ERR'][good]**2 + star['K_ERR'][good]**2)), p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')
## LOGFIT (3 parameter)
polyA, polyB, polyC, polyD = mcFit4(poly2, star['TEFF'][good], (star['J'][good] - star['K'][good]), star['TEFF_ERR'][good],\
                        (np.sqrt(star['J_ERR'][good]**2 + star['K_ERR'][good]**2)),p0=[1,1,1])
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}, {polyD:.3f}')
## POLY3 FIT (3 parameter)
polyA2, polyB2, polyC2, polyD2 = mcFit4(poly3, star['TEFF'][good], (star['J'][good] - star['K'][good]), star['TEFF_ERR'][good]\
                        , (np.sqrt(star['J_ERR'][good]**2 + star['K_ERR'][good]**2)), p0=[0,0,0,0])
print(f'POLY3: {polyA2:.3f}, {polyB2:.3}, {polyC2:.3f},{polyD2:.3f}')

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)

ax.errorbar(star['TEFF'][good],(star['J'][good] - star['K'][good]), xerr=star['TEFF_ERR'][good],
    yerr=(np.sqrt(star['J_ERR'][good]**2 + star['K_ERR'][good]**2)), ecolor='grey',fmt='none', capsize=5, zorder=0)
ax.scatter(star['TEFF'][good],(star['J'][good] - star['K'][good]),s=1,c='b',alpha=0.1)


x_plot = np.linspace(-3,1,1000) # X-PLOTING FOR FITS

ax.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
ax.plot(x_plot,logfit(x_plot, polyA, polyB, polyC, polyD), label='Fit: logfit')
ax.plot(x_plot,poly3(x_plot, polyA2, polyB2, polyC2, polyD2), label='Fit: poly3')


ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 23
#      15 good = np.where(gd)[0]
#      18 ## LINEAR FIT (2 parameter)
#      19 #slope, intercept = mcFit2(linear, star['TEFF'][good], (star['J'][good] - star['K'][good]), star['TEFF_ERR'][good],\
#      20 #                          (np.sqrt(star['J_ERR'][good]**2 + star['K_ERR'][good]**2)), p0=[0,0])
#      21 #print(f'LINEAR: {slope:.3f}, {intercept:.3f}')
#      22 ## LOGFIT (3 parameter)
# ---> 23 polyA, polyB, polyC, polyD = mcFit4(poly2, star['TEFF'][good], (star['J'][good] - star['K'][good]), star['TEFF_ERR'][good],\
#      24                         (np.sqrt(star['J_ERR'][good]**2 + star['K_ERR'][good]**2)),p0=[1,1,1])
#      25 print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}, {polyD:.3f}')
#      26 ## POLY3 FIT (3 parameter)
#
# Cell In[2], line 74, in mcFit4(func, x, y, x_err, y_err, p0)
# ...

# %% [markdown]
# ## DATA FIT 5
#
# Fit  a linear, a polynomial (poly3), and a cosfit functions and to the following selections of the data:
# 5. Select stars only with with $-10< GLAT < 10$<br>
#    __Fit GLON  vs.  VHELIO\_AVG (VERR)__<br>
# <br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code, from part 1, and plot the results here

# TWO BITWISE FLAGS FOR BAD DATA - THESE REMOVE IDENTIFIED BAD DATA            
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

# Make a Boolena Mask to remove bad data
gd = (np.bitwise_and(star['aspcapflag'], badbits) == 0) &\
     (np.bitwise_and(star['starflag'], suspectbits) == 0) & (star['GLAT'] < 10) & (star['GLAT'] > -10) &\
     (star['GLAT'] < 9999) & (~np.isnan(star['GLON'])) & (~np.isnan(star['VHELIO_AVG']))

good = np.where(gd)[0]


## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['GLON'][good], star['VHELIO_AVG'][good], 0,\
                          star['VERR'][good], p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')
## COSFIT (3 parameter)
polyA, polyB, polyC, polyD = mcFit4(cosfit, star['GLON'][good], star['VHELIO_AVG'][good], 0,\
                         star['VERR'][good],p0=[1,1,1,1])
print(f'COSFIT: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}, {polyD:.3f}')
## POLY3 FIT (3 parameter)
polyA2, polyB2, polyC2, polyD2 = mcFit4(poly3, star['GLON'][good], star['VHELIO_AVG'][good], 0\
                        , star['VERR'][good], p0=[0,0,0,0])
print(f'POLY3: {polyA:.3f}, {polyB:.3}, {polyC:.3f},{polyD:.3f}')

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
#ax.scatter(star['Fe_H_ERR'][good],star['O_Fe_ERR'][good],s=1,c='r',alpha=0.1)

ax.errorbar(star['GLON'][good],star['VHELIO_AVG'][good], xerr=0,
    yerr=(star['VERR'][good]), ecolor='grey',fmt='none', capsize=5, zorder=0)
ax.scatter(star['GLON'][good],star['VHELIO_AVG'][good],s=1,c='b',alpha=0.1)


x_plot = np.linspace(0,350,1000) # X-PLOTING FOR FITS

ax.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
ax.plot(x_plot,cosfit(x_plot, polyA, polyB, polyC, polyD), label='Fit: cosfit')
ax.plot(x_plot,poly3(x_plot, polyA2, polyB2, polyC2, polyD2), label='Fit: poly3')


ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: -0.001, -3.966
# COSFIT: -6.641, 0.979, 1.544, -3.895
# POLY3: -6.641, 0.979, 1.544,-3.895

# %% [markdown]
# ## DATA FIT 6
#
# Fit a linear, an exponential, and a polynomial (poly3) functions and to the following selections of the data:
# 6. __Fit NVISITS vs.  VSCATTER (VERR)__ For NVISITS $>= 1$<br>
# <br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code and plot the results here

# TWO BITWISE FLAGS FOR BAD DATA - THESE REMOVE IDENTIFIED BAD DATA            
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

# Make a Boolena Mask to remove bad data
gd = (np.bitwise_and(star['aspcapflag'], badbits) == 0) &\
     (np.bitwise_and(star['starflag'], suspectbits) == 0) & (star['NVISITS'] >= 1) &\
     (~np.isnan(star['NVISITS'])) & (~np.isnan(star['VSCATTER']))


good = np.where(gd)[0]


## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['NVISITS'][good], star['VSCATTER'][good], 0,\
                          star['VERR'][good], p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')
## EXPONENTIAL (3 parameter)
polyA, polyB, polyC, polyD = mcFit4(exponential, star['NVISITS'][good], star['VSCATTER'][good], 0,\
                         star['VERR'][good],p0=[-2.5,-0.37,-1,-1.7])
print(f'EXPONENTIAL: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}, {polyD:.3f}')
## POLY3 FIT (3 parameter)
polyA2, polyB2, polyC2, polyD2 = mcFit4(poly3, star['NVISITS'][good], star['VSCATTER'][good], 0\
                        , star['VERR'][good], p0=[0,0,0,0])
print(f'POLY3: {polyA2:.3f}, {polyB2:.3}, {polyC2:.3f},{polyD2:.3f}')

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
#ax.scatter(star['Fe_H_ERR'][good],star['O_Fe_ERR'][good],s=1,c='r',alpha=0.1)

ax.errorbar(star['NVISITS'][good],star['VSCATTER'][good], xerr=0,
    yerr=(star['VERR'][good]), ecolor='grey',fmt='none', capsize=5, zorder=0)
ax.scatter(star['NVISITS'][good],star['VSCATTER'][good],s=1,c='b',alpha=0.1)


x_plot = np.linspace(0,70,1000) # X-PLOTING FOR FITS

ax.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
ax.plot(x_plot,exponential(x_plot, polyA, polyB, polyC, polyD), label='Fit: exponential')
ax.plot(x_plot,poly3(x_plot, polyA2, polyB2, polyC2, polyD2), label='Fit: poly3')


ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.legend(loc='best', fontsize=18)
plt.show()

# %% [markdown]
# ## DATA FIT 7
#
# Fit  a linear and a polynomial (poly2 AND poly3) functions and to the following selections of the data:
# 7. __Fit Fe\_H,  (Fe\_H\_ERR)  vs.  NI\_FE (NI\_FE\_ERR)__<br>
# <br>
#
# For this fit of the above selection:
#
# 1. What are the best-fit values of the parameters?
# 2. Which fucntion fits the data best?
# 3. Is there a second population? (Can you fit outliers with a reasonable linear trend?)

# %%
# write your fitting code, from part 1, and plot the results here

# TWO BITWISE FLAGS FOR BAD DATA - THESE REMOVE IDENTIFIED BAD DATA            
badbits = 2**23        # aspcapstar flag - Chemistry
suspectbits = 2**16    # star flag - Stellar parameters

# Make a Boolena Mask to remove bad data
gd = (np.bitwise_and(star['aspcapflag'], badbits) == 0) &\
     (np.bitwise_and(star['starflag'], suspectbits) == 0) & (star['Fe_H'] < 1000) &\
     (star['Fe_H'] > -1000) &(star['NI_FE'] < 1000)& (star['NI_FE'] > -1000) &\
     (~np.isnan(star['Fe_H'])) & (~np.isnan(star['NI_FE']))

good = np.where(gd)[0]


## LINEAR FIT (2 parameter)
slope, intercept = mcFit2(linear, star['Fe_H'][good], star['NI_FE'][good], star['Fe_H_ERR'][good], \
                          star['NI_FE_ERR'][good], p0=[0,0])
print(f'LINEAR: {slope:.3f}, {intercept:.3f}')
## POLY2 FIT (3 parameter)
polyA, polyB, polyC, = mcFit3(poly2, star['Fe_H'][good], star['NI_FE'][good], star['Fe_H_ERR'][good], \
                         star['NI_FE_ERR'][good],p0=[1,1,1])
print(f'POLY2: {polyA:.3f}, {polyB:.3f}, {polyC:.3f}')
## POLY3 FIT (3 parameter)
polyA, polyB, polyC, polyD = mcFit4(poly3, star['Fe_H'][good], star['NI_FE'][good], star['Fe_H_ERR'][good]\
                        , star['NI_FE_ERR'][good], p0=[0,0,0,0])
print(f'POLY3: {polyA:.3f}, {polyB:.3}, {polyC:.3f},{polyD:.3f}')

# PLOT TO VERIFY FITS FILE READ IN & BAD MASK DATA
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
#ax.scatter(star['Fe_H_ERR'][good],star['O_Fe_ERR'][good],s=1,c='r',alpha=0.1)

ax.errorbar(star['Fe_H'][good],star['NI_FE'][good], xerr=star['FE_H_ERR'][good],
    yerr=(star['NI_FE_ERR'][good]), ecolor='grey',fmt='none', capsize=5, zorder=0)
ax.scatter(star['Fe_H'][good],star['NI_FE'][good],s=1,c='b',alpha=0.1)


x_plot = np.linspace(-5,1,1000) # X-PLOTING FOR FITS

ax.plot(x_plot,linear(x_plot, slope, intercept), label='Fit: linear')
ax.plot(x_plot,poly2(x_plot, polyA, polyB, polyC), label='Fit: poly2')
ax.plot(x_plot,poly3(x_plot, polyA, polyB, polyC, polyD), label='Fit: poly3')


ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.legend(loc='best', fontsize=18)
plt.show()
# Out:
# LINEAR: 0.013, 0.016
# POLY2: 0.024, 0.038, 0.017
# POLY3: -0.021, -0.0182, 0.026,0.018
